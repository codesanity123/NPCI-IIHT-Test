# %% [markdown]
# Sort a Linked List into a Queue

# %%
class Queue:
 
    def __init__(self, c):
         
        self.queue = []
        self.front = self.rear = 0
        self.capacity = c
 
    def queueEnqueue(self, data):
 

        if(self.capacity == self.rear):
            print("\nQueue is full")

        else:
            self.queue.append(data)
            self.rear += 1

    def queueDequeue(self):
 
        # If queue is empty
        if(self.front == self.rear):
            print("Queue is empty")
 
  
        else:
            x = self.queue.pop(0)
            self.rear -= 1

    def queueDisplay(self):
         
        if(self.front == self.rear):
            print("\nQueue is Empty")
 

        for i in range(self.front, self.rear):
                print(self.queue[i], end = " ")
        print ()

    def queueFront(self):
         
        if(self.front == self.rear):
            print("\nQueue is Empty")
 
        print("\nFront Element is:",
              self.queue[self.front])
         
class Node:  
        def __init__(self,data):  
            self.data = data  
            self.next = None  
              
class SortList:  
      
        def __init__(self):  
            self.head = None  
            self.tail = None  
              
    
        def addNode(self, data):  
            
            newNode = Node(data)  
              
            
            if(self.head == None):  
                
                self.head = newNode  
                self.tail = newNode  
            else:  
                
                self.tail.next = newNode           
                self.tail = newNode  
                  
        
        def sortList(self):  
            
            current = self.head  
            index = None  
              
            if(self.head == None):  
                return; 
            else:  
                while(current != None):   
                    index = current.next   
                    while(index != None):                  
                        if(current.data > index.data):  
                            temp = current.data  
                            current.data = index.data;  
                            index.data = temp  
                        index = index.next  
                    current = current.next  
            q1=Queue(10)
            current = self.head 
            while(current != None): 
              q1.queueEnqueue(current.data)  
              current = current.next               
            q1.queueDisplay() 

        def display(self):  
       
         current = self.head 
         if(self.head == None):  
            print("List is empty")  
            return;  
         while(current != None): 
            print(current.data, end = " ") 
            current = current.next 
     
       
sList = SortList()  
              
sList.addNode(6)  
sList.addNode(12)  
sList.addNode(2)  
sList.addNode(15)  
sList.addNode(3)  
sList.addNode(9)  
sList.addNode(47)  
sList.addNode(8)  
       
print("Original list: ")  
sList.display();  

print("\nSorted List after transformed to Queue: ") 
sList.sortList()
# Out:
# Original list:
# 6 12 2 15 3 9 47 8
# Sorted List after transformed to Queue:
# 2 3 6 8 9 12 15 47
